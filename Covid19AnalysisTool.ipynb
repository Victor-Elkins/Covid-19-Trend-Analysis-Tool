# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

df = pd.read_csv('us-states.csv') #data of states covid deaths/cases and daily tracking of them
ds = pd.read_csv('us.csv') #same data but no state specification (more general)

# %%
df.head(10)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0
# 5  2020-01-25  California     6      1       0
# 6  2020-01-25    Illinois    17      1       0
# 7  2020-01-25  Washington    53      1       0
# 8  2020-01-26     Arizona     4      1       0
# 9  2020-01-26  California     6      2       0

# %%
df.rename(columns = {'date':'ObservationDate','state':'State','fips':'State Code','cases':'Cases Total','deaths':'Deaths Total'})
# Out:
#       ObservationDate province/state  State Code  Cases Total  Deaths Total
# 0          2020-01-21     Washington          53            1             0
# 1          2020-01-22     Washington          53            1             0
# 2          2020-01-23     Washington          53            1             0
# 3          2020-01-24       Illinois          17            1             0
# 4          2020-01-24     Washington          53            1             0
# ...               ...            ...         ...          ...           ...
# 47489      2022-07-08       Virginia          51      1890973         20740
# 47490      2022-07-08     Washington          53      1688279         13384
# 47491      2022-07-08  West Virginia          54       537443          7069
# 47492      2022-07-08      Wisconsin          55      1738225         14836
# 47493      2022-07-08        Wyoming          56       165619          1834
#
# [47494 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df['date'])


imputer = SimpleImputer(strategy='constant')
df2 = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
states = df['state'].unique()
print(states) #total length is 56 because the dataset includes territories such as Guam, Puerto rico etc. as seen below
len(states)
# Out:
# ['Washington' 'Illinois' 'California' 'Arizona' 'Massachusetts'
#  'Wisconsin' 'Texas' 'Nebraska' 'Utah' 'Oregon' 'Florida' 'New York'
#  'Rhode Island' 'Georgia' 'New Hampshire' 'North Carolina' 'New Jersey'
#  'Colorado' 'Maryland' 'Nevada' 'Tennessee' 'Hawaii' 'Indiana' 'Kentucky'
#  'Minnesota' 'Oklahoma' 'Pennsylvania' 'South Carolina'
#  'District of Columbia' 'Kansas' 'Missouri' 'Vermont' 'Virginia'
#  'Connecticut' 'Iowa' 'Louisiana' 'Ohio' 'Michigan' 'South Dakota'
#  'Arkansas' 'Delaware' 'Mississippi' 'New Mexico' 'North Dakota' 'Wyoming'
#  'Alaska' 'Maine' 'Alabama' 'Idaho' 'Montana' 'Puerto Rico'
#  'Virgin Islands' 'Guam' 'West Virginia' 'Northern Mariana Islands'
#  'American Samoa']
# 56

# %%
for idx in range(0,len(states)):
    C = df[df['state']==states[idx]].reset_index()        
    plt.scatter(np.arange(0,len(C)),C['cases'],color='white',label='Confirmed cases')
    
    plt.title(states[idx])
    plt.xlabel('Days since the first case(1/21/2020)')
    plt.ylabel('Number of cases ')
    plt.legend()
    plt.show()

# %%
for idx in range(0,len(states)):
    plt.style.use("dark_background")
    C = df[df['state']==states[idx]].reset_index()        
    plt.scatter(np.arange(0,len(C)),C['deaths'],color='white',label='Confirmed Deaths')
    
    plt.title(states[idx])
    plt.xlabel('Days since the first case(1/21/2020)')
    plt.ylabel('Number of cases ')
    plt.legend()
    plt.show()

# %%
dates = ds['date'].unique()
len(dates)
# Out:
# 900

# %%
print('created 900 days after the introduction of the Covid-19 Pandemic information is subject to change')
# Out:
# created 900 days after the introduction of the Covid-19 Pandemic information is subject to change
